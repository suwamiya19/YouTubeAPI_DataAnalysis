# %%
from googleapiclient.discovery import build 
import pandas as pd
from IPython.display import JSON
from dateutil import parser
import isodate

#import data visualization packages

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
api_key= 'AIzaSyDXOWxWVdocxNJYLxKrjyJQR9vGKo011O4'

# %%
api_service_name = "youtube"
api_version = "v3"
channel_ids = ["UC5_4POQX0WtMhUpRsh-YQhA"
              #to add more channel ids
              ]
youtube = build(
    api_service_name, api_version, developerKey=api_key)
#request = youtube.channels().list(part="snippet,contentDetails,statistics",id=",".join(channel_ids))
#response = request.execute()
#print(response)

# %%
def getChannelStats(youtube,channel_ids):
    
    stat_data=[];
    
    request = youtube.channels().list(part="snippet,contentDetails,statistics",id=",".join(channel_ids))
    response = request.execute()
    
    #looping through each channel item & creating a dictionary
    for item in response["items"]:
        data={"ChannelName": item["snippet"]["title"],
              "SubscribersCount" : item["statistics"]["subscriberCount"],
              "NoofVideos" : item["statistics"]["videoCount"],
              "Playlist" : item["contentDetails"]["relatedPlaylists"]["uploads"]
             }
        stat_data.append(data)
        
    #returning channel stat as a dataframe    
    return(stat_data)

# %%
ChannelStatistics = getChannelStats(youtube,channel_ids)
ChannelStatistics
# Out:
# [{'ChannelName': 'The Cheeky DNA',
#   'SubscribersCount': '303000',
#   'NoofVideos': '236',
#   'Playlist': 'UU5_4POQX0WtMhUpRsh-YQhA'}]

# %%
pd.DataFrame(ChannelStatistics)
# Out:
#       ChannelName SubscribersCount NoofVideos                  Playlist
# 0  The Cheeky DNA           303000        236  UU5_4POQX0WtMhUpRsh-YQhA

# %%
#getting list of all video ids
def getVideoIds(youtube,playlist_id):
    video_ids=[]
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        maxResults=50,
        playlistId=playlist_id
    )
    response = request.execute()
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
    
    nextPageToken = response.get('nextPageToken')
    
    while nextPageToken is not None:
        request = youtube.playlistItems().list(
        part="snippet,contentDetails",
            maxResults=50,
            pageToken=nextPageToken,
            playlistId=playlist_id
        )
        response = request.execute()
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])

        nextPageToken = response.get('nextPageToken')

    return video_ids


    # for i in range(int(int(NoofVideos)/50)):
#             request = youtube.playlistItems().list(
#                 part="snippet,contentDetails",
#                 maxResults=50,
#                 pageToken=nextPageToken,
#                 playlistId=playlist_id
#             )
#             response = request.execute()
#             for item in response['items']:
#                 video_ids.append(item['contentDetails']['videoId'])
                
#             nextPageToken = response.get('nextPageToken')

# %%
playlist_id = ChannelStatistics[0]['Playlist'] 
# NoofVideos = ChannelStatistics[0]['NoofVideos']
video_ids = getVideoIds(youtube,playlist_id)
#print(NoofVideos)
#print(int(NoofVideos)/50)
print(len(video_ids))
# Out:
# 235

# %%
#getting info of all vidoes


def getVideoInfo(youtube,video_ids):
    
    all_video_info=[];
    
    for i in range(0,len(video_ids),50):
        
        request = youtube.videos().list(
                part="snippet,contentDetails,statistics",
                id= ','.join(video_ids[i:i+50])
            )
        response = request.execute()

        statstokeep ={}

        for item in response["items"]:
            statstokeep = {
                "snippet" : ["channelTitle","title","description","tags","publishedAt"],
                "statistics" : ["viewCount","likeCount","favoriteCount","commentCount"],
                "contentDetails" : ["duration","definition","caption"]
            }
            video_info={};
            video_info['video_id']=item['id'];

            for k in statstokeep.keys():
                for v in statstokeep[k]:
                    try:
                        video_info[v]=item[k][v]
                    except:
                        video_info[v]=None;
            all_video_info.append(video_info);

    return pd.DataFrame(all_video_info)

# %%
all_video_info = getVideoInfo(youtube,video_ids)
all_video_info
# Out:
#         video_id    channelTitle  \
# 0    eQ9M0V3LzNo  The Cheeky DNA
# 1    reP8qagFNTM  The Cheeky DNA
# 2    HVXs9Rpt2V0  The Cheeky DNA
# 3    DdAMzQrJun4  The Cheeky DNA
# 4    RL_FZxLqKdY  The Cheeky DNA
# ..           ...             ...
# 230  Qk7p-PcihyI  The Cheeky DNA
# 231  O4BbJZmsqIo  The Cheeky DNA
# 232  pC00izgrhi0  The Cheeky DNA
# 233  8FvCByN5SsQ  The Cheeky DNA
# 234  F3TiBBPx9N0  The Cheeky DNA
#
#                                                  title  \
# 0    Launching 2023 calendars #shorts #2023 #calend...
# 1    Every White T-Shirt Ever #shorts #comedy #funn...
# 2    Mom of Friend- Who is the worst??😂 #shorts #co...
# 3    Select my Birthday Dress #shorts #comedy #come...
# 4    Independence Day speech be like #shorts #indep...
# ..                                                 ...
# 230                              HOW WE GIRLS WORKOUT?
# 231             Things Indian Dads Say To Uber Drivers
# 232                  THINGS COLLEGE TEACHERS (MAM) DO!
# 233  SIKKIM TRIP ! A TRAVEL GUIDE! COLLEGE TOUR! MC...
# 234                    The Cheeky DNA || The Beginning
#
#                                            description  \
# 0    Shop now out at www.thecheekydna.com\n\nModern...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 230  Do any of you find every possible reason to po...
# 231  We are addicted to Uber these days and our par...
# 232  I am Subhalaxmi Parida and I'm a half-baked zo...
# 233  I decided to film our entire M.Sc. trip. Picke...
# 234  A half-baked zoologist's journey towards happi...
#
#                                                   tags           publishedAt  \
# 0                                                 None  2022-12-30T11:30:09Z
# 1                                                 None  2022-11-14T11:00:20Z
# 2                                                 None  2022-09-25T12:15:19Z
# 3                                                 None  2022-08-18T11:39:01Z
# 4                                                 None  2022-08-16T03:10:58Z
# ..                                                 ...                   ...
# 230  [cheeky dna, cheeky, subha, bha, subhalaxmi, p...  2017-10-06T05:00:04Z
# 231  [cheeky dna, cheeky, subha, bha, subhalaxmi, p...  2017-06-10T13:44:41Z
# 232  [teacher, miss, mam, subha, subhalaxmi, parida...  2017-03-26T11:39:58Z
# 233  [mcc, msc, zoology, sikkim, lachung, 2017, yum...  2017-02-12T03:58:34Z
# 234  [iisuperwomanii, colleen ballinger, miranda si...  2017-01-01T10:22:28Z
#
#     viewCount likeCount favoriteCount commentCount  duration definition  \
# 0        2883       131             0            2     PT41S         hd
# 1      111612      4861             0           25     PT28S         hd
# 2      120429      4791             0           21    PT1M1S         hd
# 3      153643      5734             0          253    PT1M1S         hd
# 4      261824     14881             0           47    PT1M1S         hd
# ..        ...       ...           ...          ...       ...        ...
# 230    112063      3427             0          182   PT6M14S         hd
# 231     22888       670             0           42    PT6M9S         hd
# 232    233450      7283             0          357   PT6M42S         hd
# 233     11308       283             0           14  PT12M54S         hd
# 234     35535      1334             0           64   PT6M17S         hd
#
#     caption
# 0     false
# 1     false
# 2     false
# 3     false
# 4     false
# ..      ...
# 230    true
# 231   false
# 232   false
# 233   false
# 234   false
#
# [235 rows x 13 columns]

# %%
#DATA PREPROCESSING
#-------------------

# %%
# NULL VALUE CHECK

all_video_info.isnull().any()
# Out:
# video_id         False
# channelTitle     False
# title            False
# description      False
# tags              True
# publishedAt      False
# viewCount        False
# likeCount        False
# favoriteCount    False
# commentCount      True
# duration         False
# definition       False
# caption          False
# dtype: bool

# %%
# DATATYPE CHECK

all_video_info.dtypes
# Out:
# video_id         object
# channelTitle     object
# title            object
# description      object
# tags             object
# publishedAt      object
# viewCount        object
# likeCount        object
# favoriteCount    object
# commentCount     object
# duration         object
# definition       object
# caption          object
# dtype: object

# %%
# CONVERTING TO NUMERIC DATATYPE

numeric_columns = ['viewCount','likeCount','favoriteCount','commentCount']
all_video_info[numeric_columns]=all_video_info[numeric_columns].apply(pd.to_numeric,errors='coerce',axis=1)

all_video_info.dtypes
# Out:
# video_id          object
# channelTitle      object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount        float64
# likeCount        float64
# favoriteCount    float64
# commentCount     float64
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
# PUBLISH DAY IN THE WEEK

all_video_info['publishedAt']=all_video_info['publishedAt'].apply(lambda x:parser.parse(x))
all_video_info['publishedDay']=all_video_info['publishedAt'].apply(lambda x:x.strftime("%A"))

# %%
all_video_info['durationInSecs']=all_video_info['duration'].apply(lambda x:isodate.parse_duration(x))
all_video_info['durationInSecs']=all_video_info['durationInSecs'].astype('timedelta64[s]')

# %%
#NO OF TAGS

all_video_info['noOfTags']=all_video_info['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
all_video_info
# Out:
#         video_id    channelTitle  \
# 0    eQ9M0V3LzNo  The Cheeky DNA
# 1    reP8qagFNTM  The Cheeky DNA
# 2    HVXs9Rpt2V0  The Cheeky DNA
# 3    DdAMzQrJun4  The Cheeky DNA
# 4    RL_FZxLqKdY  The Cheeky DNA
# ..           ...             ...
# 230  Qk7p-PcihyI  The Cheeky DNA
# 231  O4BbJZmsqIo  The Cheeky DNA
# 232  pC00izgrhi0  The Cheeky DNA
# 233  8FvCByN5SsQ  The Cheeky DNA
# 234  F3TiBBPx9N0  The Cheeky DNA
#
#                                                  title  \
# 0    Launching 2023 calendars #shorts #2023 #calend...
# 1    Every White T-Shirt Ever #shorts #comedy #funn...
# 2    Mom of Friend- Who is the worst??😂 #shorts #co...
# 3    Select my Birthday Dress #shorts #comedy #come...
# 4    Independence Day speech be like #shorts #indep...
# ..                                                 ...
# 230                              HOW WE GIRLS WORKOUT?
# 231             Things Indian Dads Say To Uber Drivers
# 232                  THINGS COLLEGE TEACHERS (MAM) DO!
# 233  SIKKIM TRIP ! A TRAVEL GUIDE! COLLEGE TOUR! MC...
# 234                    The Cheeky DNA || The Beginning
#
#                                            description  \
# 0    Shop now out at www.thecheekydna.com\n\nModern...
# 1
# 2
# 3
# 4
# ..                                                 ...
# 230  Do any of you find every possible reason to po...
# 231  We are addicted to Uber these days and our par...
# 232  I am Subhalaxmi Parida and I'm a half-baked zo...
# 233  I decided to film our entire M.Sc. trip. Picke...
# 234  A half-baked zoologist's journey towards happi...
#
#                                                   tags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                 None
# 4                                                 None
# ..                                                 ...
# 230  [cheeky dna, cheeky, subha, bha, subhalaxmi, p...
# 231  [cheeky dna, cheeky, subha, bha, subhalaxmi, p...
# 232  [teacher, miss, mam, subha, subhalaxmi, parida...
# 233  [mcc, msc, zoology, sikkim, lachung, 2017, yum...
# 234  [iisuperwomanii, colleen ballinger, miranda si...
#
#                   publishedAt  viewCount  likeCount  favoriteCount  \
# 0   2022-12-30 11:30:09+00:00     2883.0      131.0            0.0
# 1   2022-11-14 11:00:20+00:00   111612.0     4861.0            0.0
# 2   2022-09-25 12:15:19+00:00   120429.0     4791.0            0.0
# 3   2022-08-18 11:39:01+00:00   153643.0     5734.0            0.0
# 4   2022-08-16 03:10:58+00:00   261824.0    14881.0            0.0
# ..                        ...        ...        ...            ...
# 230 2017-10-06 05:00:04+00:00   112063.0     3427.0            0.0
# 231 2017-06-10 13:44:41+00:00    22888.0      670.0            0.0
# 232 2017-03-26 11:39:58+00:00   233450.0     7283.0            0.0
# 233 2017-02-12 03:58:34+00:00    11308.0      283.0            0.0
# 234 2017-01-01 10:22:28+00:00    35535.0     1334.0            0.0
#
#      commentCount  duration definition caption publishedDay  durationInSecs  \
# 0             2.0     PT41S         hd   false       Friday            41.0
# 1            25.0     PT28S         hd   false       Monday            28.0
# 2            21.0    PT1M1S         hd   false       Sunday            61.0
# 3           253.0    PT1M1S         hd   false     Thursday            61.0
# 4            47.0    PT1M1S         hd   false      Tuesday            61.0
# ..            ...       ...        ...     ...          ...             ...
# 230         182.0   PT6M14S         hd    true       Friday           374.0
# 231          42.0    PT6M9S         hd   false     Saturday           369.0
# 232         357.0   PT6M42S         hd   false       Sunday           402.0
# 233          14.0  PT12M54S         hd   false       Sunday           774.0
# 234          64.0   PT6M17S         hd   false       Sunday           377.0
#
#      noOfTags
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 230        35
# 231        30
# 232        37
# 233        20
# 234        14
#
# [235 rows x 16 columns]

# %%
#DATA ANALYSIS

# %% [markdown]
# Exploratory Data Analysis
# ---------------------------

# %% [markdown]
# 1. BEST PERFORMING VIDEOS

# %%
ax= sns.barplot(x='title',y='viewCount',data=all_video_info.sort_values('viewCount', ascending=False)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.2f}'.format(x/1000000) + 'M'))

# %% [markdown]
# 2. WORST PERFORMING VIDEOS

# %%
ax= sns.barplot(x='title',y='viewCount',data=all_video_info.sort_values('viewCount', ascending=True)[0:9])
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation=90)
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.2f}'.format(x/1000) + 'K'))

# %% [markdown]
# 4. View distribution across videos

# %%
sns.violinplot(all_video_info['viewCount'])
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x,pos:'{:,.2f}'.format(x/1000) + 'K'))
